# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
# Tarayıcıyı başlat
options = Options()
#options.add_argument("--headless")  # Tarayıcıyı arka planda çalıştır (görmek istersen kaldırabilirsin)
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# %%
# Hepsiburada ürün sayfası
url = "https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?siralama=yorumsayisi"

# Sayfayı aç
driver.get(url)
time.sleep(3)  # Sayfanın yüklenmesini bekle

# %%
# Tüm ürünler için tutacak liste
all_products = []

# %%
products= driver.find_elements(By.CLASS_NAME, "moria-ProductCard-iymOAa jYJVkr s8ov74kzrxz")

# %%
products
# Out:
# []

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# Tarayıcıyı başlat
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Hepsiburada laptop sayfası
url = "https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?siralama=yorumsayisi"

# Sayfayı aç
driver.get(url)
time.sleep(5)  # Sayfanın yüklenmesini bekle

# Çerezleri kabul etme (Eğer varsa)
try:
    cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
    cookie_button.click()
    print("✅ Çerezler kabul edildi!")
    time.sleep(2)
except:
    print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Ürün Başlıklarını ve Altındaki Bilgileri Al**
try:
    product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
    for title in product_titles:
        print("🖥️ Ürün Adı:", title.text.strip())  # Ürün başlığını yazdır

        # **Altındaki elementi bul (örneğin fiyat bilgisi veya ek açıklama)**
        try:
            product_info = title.find_element(By.XPATH, "./following-sibling::*")  # Hemen altındaki öğeyi bul
            print("📌 Ek Bilgi:", product_info.text.strip())  # Altındaki bilgiyi yazdır
        except:
            print("⚠️ Ek bilgi bulunamadı.")

        print("-" * 50)  # Ayırıcı çizgi ekle
except:
    print("⚠️ Ürün başlıkları bulunamadı!")

# Tarayıcıyı kapat
driver.quit()
# Out:
# ✅ Çerezler kabul edildi!
# 🖥️ Ürün Adı: Apple MacBook Air M1 Çip 8GB 256GB SSD macOS 13" QHD Taşınabilir Bilgisayar Uzay Grisi MGN63TU/A
# ⚠️ Ek bilgi bulunamadı.
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G870.1342-BFA0X-B Intel Core i5 13420H 16GB 1TB SSD RTX4050 Freedos 15.6" Taşınabilir Bilgisayar
# ⚠️ Ek bilgi bulunamadı.
# --------------------------------------------------
# 🖥️ Ürün Adı: Monster Tulpar T7 V20.6.2 Intel Core i7 13700H 32 GB RAM 1 TB SSD 8 GB RTX 4060 FreeDOS 17,3" FHD 144 Hz Oyun Bilgisayarı
# ⚠️ Ek bilgi bulunamadı.
# --------------------------------------------------
# 🖥️ Ürün Adı: MSI THIN GF63 12VE-082XTR Intel Core i5 12450H 8GB 512GB SSD RTX4050 Freedos 15.6" FHD 144Hz Taşınabilir Bilgisayar
# ⚠️ Ek bilgi bulunamadı.
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G770.1245-BFJ0X-B Intel Core i5 12450H 16GB 1TB SSD RTX3050 Freedos 15.6" FHD Taşınabilir Bilgisayar
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# Tarayıcıyı başlat
options = Options()
# options.add_argument("--headless")  # Arka planda çalıştırmak için (görmek istersen kaldır)
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Hepsiburada laptoplar sayfası (en çok yorum alan)
url = "https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?siralama=yorumsayisi"

# Sayfayı aç
driver.get(url)
time.sleep(5)  # Sayfanın yüklenmesini bekle

# **📌 Çerezleri kabul et (varsa)**
try:
    cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
    cookie_button.click()
    print("✅ Çerezler kabul edildi!")
    time.sleep(2)
except:
    print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Tüm Ürünler İçin Boş Liste**
all_products = []

# **📌 Ürün Başlıklarını ve Yorum Sayılarını Çek**
try:
    product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
    
    for title in product_titles:
        product_name = title.text.strip()  # Ürün adını al
        print("🖥️ Ürün Adı:", product_name)

        # **📌 Yorum Sayısını Bulmaya Çalış**
        try:
            review_count = title.find_element(By.XPATH, "./following::div[contains(@class, 'moria-ProductCard')]").text.strip()
            print("💬 Yorum Sayısı:", review_count)
        except:
            review_count = "0"
            print("⚠️ Yorum sayısı bulunamadı.")

        # **📌 Listeye Ekle**
        all_products.append((product_name, review_count))
        
        print("-" * 50)  # Ayırıcı çizgi ekle
except:
    print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
# Out:
# ⚠️ Çerez butonu bulunamadı, devam ediliyor...
# 🖥️ Ürün Adı: Apple MacBook Air M1 Çip 8GB 256GB SSD macOS 13" QHD Taşınabilir Bilgisayar Uzay Grisi MGN63TU/A
# 💬 Yorum Sayısı: 1.512
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G870.1342-BFA0X-B Intel Core i5 13420H 16GB 1TB SSD RTX4050 Freedos 15.6" Taşınabilir Bilgisayar
# 💬 Yorum Sayısı: 947
# --------------------------------------------------
# 🖥️ Ürün Adı: Monster Tulpar T7 V20.6.2 Intel Core i7 13700H 32 GB RAM 1 TB SSD 8 GB RTX 4060 FreeDOS 17,3" FHD 144 Hz Oyun Bilgisayarı
# 💬 Yorum Sayısı: 938
# --------------------------------------------------
# 🖥️ Ürün Adı: MSI THIN GF63 12VE-082XTR Intel Core i5 12450H 8GB 512GB SSD RTX4050 Freedos 15.6" FHD 144Hz Taşınabilir Bilgisayar
# 💬 Yorum Sayısı: 874
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G770.1245-BFJ0X-B Intel Core i5 12450H 16GB 1TB SSD RTX3050 Freedos 15.6" FHD Taşınabilir Bilgisayar
# ...

# %%
# **📌 Sonuçları Yazdır ve Yorum Sayılarının Toplamını Hesapla**
total_reviews = 0  # Toplam yorum sayısı

print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    #print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
    
    # **Yorum Sayısını Noktadan Temizleyerek Tam Sayıya Çevir**
    try:
        reviews_clean = int(float(reviews.replace(".", "")))  # 1.512 → 1512
        total_reviews += reviews_clean
    except ValueError:
        print(f"⚠️ Hatalı yorum sayısı algılandı: {reviews}")  # Eğer hata olursa

# **📌 Toplam Yorum Sayısını Yazdır**
print(f"\n🔢 Toplam Yorum Sayısı: {total_reviews}")
print(f"\n🔢 Toplam Ürün Sayısı: {len(all_products)}")
# Out:
# ✅ Tüm Ürünler ve Yorum Sayıları:
#
# 🔢 Toplam Yorum Sayısı: 18101
#
# 🔢 Toplam Ürün Sayısı: 36

# %%
len(all_products)
# Out:
# 36

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# Tarayıcıyı başlat
options = Options()
# options.add_argument("--headless")  # Arka planda çalıştırmak için (görmek istersen kaldır)
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Hepsiburada laptoplar sayfası (en çok yorum alan)
url = "https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?siralama=yorumsayisi"

# Sayfayı aç
driver.get(url)
time.sleep(5)  # Sayfanın yüklenmesini bekle

# **📌 Çerezleri kabul et (varsa)**
try:
    cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
    cookie_button.click()
    print("✅ Çerezler kabul edildi!")
    time.sleep(2)
except:
    print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Tüm Ürünler İçin Boş Liste**
all_products = []

def get_products():
    # **📌 Ürün Başlıklarını ve Yorum Sayılarını Çek**
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al
            print("🖥️ Ürün Adı:", product_name)
    
            # **📌 Yorum Sayısını Bulmaya Çalış**
            try:
                review_count = title.find_element(By.XPATH, "./following::div[contains(@class, 'moria-ProductCard')]").text.strip()
                print("💬 Yorum Sayısı:", review_count)
            except:
                review_count = "0"
                print("⚠️ Yorum sayısı bulunamadı.")
    
            # **📌 Listeye Ekle**
            all_products.append((product_name, review_count))
            
            print("-" * 50)  # Ayırıcı çizgi ekle
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

#ilk sayfadakiler gelecek
get_products()

# **📌 "Daha Fazla Ürün Göster" Butonuna Tıklama** 
while True: 
    try: 
        load_more_button = driver.find_element(By.XPATH, "//button[@data-test-id='load-more-button']") 
        driver.execute_script("arguments[0].click();", load_more_button) 
        print("🔄 'Daha Fazla Ürün Göster' butonuna tıklandı.") 
        time.sleep(3) # Yeni ürünlerin yüklenmesini bekle 
        
        # **📌 Yeni Gelen Ürünleri Listeye Ekle** 
        get_products() 
    except:
        print("✅ Tüm ürünler yüklendi!")
        break # **Eğer buton bulunamazsa döngüyü kır** 

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
# Out:
# ⚠️ Çerez butonu bulunamadı, devam ediliyor...
# 🖥️ Ürün Adı: Apple MacBook Air M1 Çip 8GB 256GB SSD macOS 13" QHD Taşınabilir Bilgisayar Uzay Grisi MGN63TU/A
# 💬 Yorum Sayısı: 1.512
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G870.1342-BFA0X-B Intel Core i5 13420H 16GB 1TB SSD RTX4050 Freedos 15.6" Taşınabilir Bilgisayar
# 💬 Yorum Sayısı: 947
# --------------------------------------------------
# 🖥️ Ürün Adı: Monster Tulpar T7 V20.6.2 Intel Core i7 13700H 32 GB RAM 1 TB SSD 8 GB RTX 4060 FreeDOS 17,3" FHD 144 Hz Oyun Bilgisayarı
# 💬 Yorum Sayısı: 938
# --------------------------------------------------
# 🖥️ Ürün Adı: MSI THIN GF63 12VE-082XTR Intel Core i5 12450H 8GB 512GB SSD RTX4050 Freedos 15.6" FHD 144Hz Taşınabilir Bilgisayar
# 💬 Yorum Sayısı: 874
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G770.1245-BFJ0X-B Intel Core i5 12450H 16GB 1TB SSD RTX3050 Freedos 15.6" FHD Taşınabilir Bilgisayar
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# **📌 Tarayıcıyı başlat**
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# **📌 Hepsiburada laptoplar sayfası (en çok yorum alan)**
url = "https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?siralama=yorumsayisi"
driver.get(url)
time.sleep(5)  # **Sayfanın yüklenmesini bekle**

# **📌 Çerezleri kabul et (varsa)**
try:
    cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
    cookie_button.click()
    print("✅ Çerezler kabul edildi!")
    time.sleep(2)
except:
    print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Tüm Ürünler İçin Boş Liste**
all_products = []

def get_products():
    """Sayfadaki tüm ürünleri listeye ekler."""
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al
            print("🖥️ Ürün Adı:", product_name)
    
            # **📌 Yorum Sayısını Bulmaya Çalış**
            try:
                review_count = title.find_element(By.XPATH, "./following::div[contains(@class, 'moria-ProductCard')]").text.strip()
                print("💬 Yorum Sayısı:", review_count)
            except:
                review_count = "0"
                print("⚠️ Yorum sayısı bulunamadı.")
    
            # **📌 Listeye Ekle**
            all_products.append((product_name, review_count))
            
            print("-" * 50)  # Ayırıcı çizgi ekle
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 İlk Sayfadaki Ürünleri Yükle**
get_products()

# **📌 Sayfanın Sonuna Kadar Kaydır (Lazy Load için)**
def scroll_to_bottom():
    """Sayfanın en altına kadar kaydırma işlemi yapar."""
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(5)  # **Yeni ürünlerin yüklenmesini bekle**
        new_height = driver.execute_script("return document.body.scrollHeight")
        
        if new_height == last_height:
            break  # **Eğer sayfa boyutu değişmediyse, çık**
        last_height = new_height

# **📌 "Daha Fazla Ürün Göster" Butonuna Tıklama + Scroll Ekleme**
while True:
    try:
        # **📌 Önce Butona Tıkla**
        load_more_button = driver.find_element(By.XPATH, "//button[@data-test-id='load-more-button']")
        driver.execute_script("arguments[0].click();", load_more_button)
        print("🔄 'Daha Fazla Ürün Göster' butonuna tıklandı.")
        time.sleep(3)  # Yeni ürünlerin yüklenmesini bekle
        
        # **📌 Sonra Sayfanın En Altına Kaydır**
        scroll_to_bottom()

        # **📌 Yeni Gelen Ürünleri Listeye Ekle**
        get_products()
    except:
        print("✅ Tüm ürünler yüklendi!")
        break  # **Eğer buton bulunamazsa döngüyü kır**

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
# Out:
# ✅ Çerezler kabul edildi!
# 🖥️ Ürün Adı: Apple MacBook Air M1 Çip 8GB 256GB SSD macOS 13" QHD Taşınabilir Bilgisayar Uzay Grisi MGN63TU/A
# 💬 Yorum Sayısı: 1.512
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G870.1342-BFA0X-B Intel Core i5 13420H 16GB 1TB SSD RTX4050 Freedos 15.6" Taşınabilir Bilgisayar
# 💬 Yorum Sayısı: 947
# --------------------------------------------------
# 🖥️ Ürün Adı: Monster Tulpar T7 V20.6.2 Intel Core i7 13700H 32 GB RAM 1 TB SSD 8 GB RTX 4060 FreeDOS 17,3" FHD 144 Hz Oyun Bilgisayarı
# 💬 Yorum Sayısı: 938
# --------------------------------------------------
# 🖥️ Ürün Adı: MSI THIN GF63 12VE-082XTR Intel Core i5 12450H 8GB 512GB SSD RTX4050 Freedos 15.6" FHD 144Hz Taşınabilir Bilgisayar
# 💬 Yorum Sayısı: 874
# --------------------------------------------------
# 🖥️ Ürün Adı: Casper Excalibur G770.1245-BFJ0X-B Intel Core i5 12450H 16GB 1TB SSD RTX3050 Freedos 15.6" FHD Taşınabilir Bilgisayar
# 💬 Yorum Sayısı: 818
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# **📌 Tarayıcıyı başlat**
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# **📌 Çerezleri kabul etme fonksiyonu**
def accept_cookies():
    try:
        cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        cookie_button.click()
        print("✅ Çerezler kabul edildi!")
        time.sleep(2)
    except:
        print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Ürünleri çekme fonksiyonu**
def get_products():
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al
            try:
                review_count = title.find_element(By.XPATH, "./following::div[contains(@class, 'moria-ProductCard')]").text.strip()
            except:
                review_count = "0"  # Eğer yorum bulunamazsa 0 ata
            all_products.append((product_name, review_count))
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 Sayfa Sayısı ve URL Güncelleme**
max_pages = 50  # Kaç sayfa çekmek istediğini belirle
all_products = []  # Tüm ürünleri saklamak için liste

for page_num in range(1, max_pages + 1):
    url = f"https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa={page_num}"
    print(f"\n🌍 Sayfa {page_num} Yükleniyor: {url}")
    
    # Sayfayı aç
    driver.get(url)
    time.sleep(5)  # **Sayfanın yüklenmesini bekle**
    
    # **Çerezleri kabul et (ilk sayfada)**
    if page_num == 1:
        accept_cookies()

    # **Ürünleri çek**
    get_products()

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
# Out:
# 🌍 Sayfa 1 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=1
# ⚠️ Çerez butonu bulunamadı, devam ediliyor...
#
# 🌍 Sayfa 2 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=2
#
# 🌍 Sayfa 3 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=3
#
# 🌍 Sayfa 4 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=4
#
# 🌍 Sayfa 5 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=5
#
# 🌍 Sayfa 6 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=6
#
# 🌍 Sayfa 7 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=7
#
# 🌍 Sayfa 8 Yükleniyor: https://www.hepsiburada.com/bilgisayarlar-c-3000500?siralama=yorumsayisi&sayfa=8
#
# ...

# %%
# **📌 Sonuçları Yazdır ve Yorum Sayılarının Toplamını Hesapla**
total_reviews = 0  # Toplam yorum sayısı

print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    #print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
    
    # **Yorum Sayısını Noktadan Temizleyerek Tam Sayıya Çevir**
    try:
        reviews_clean = int(float(reviews.replace(".", "")))  # 1.512 → 1512
        total_reviews += reviews_clean
    except ValueError:
        print(f"⚠️ Hatalı yorum sayısı algılandı: {reviews}")  # Eğer hata olursa

# **📌 Toplam Yorum Sayısını Yazdır**
print(f"\n🔢 Toplam Yorum Sayısı: {total_reviews}")
print(f"\n🔢 Toplam Ürün Sayısı: {len(all_products)}")
# Out:
# ✅ Tüm Ürünler ve Yorum Sayıları:
#
# 🔢 Toplam Yorum Sayısı: 63686
#
# 🔢 Toplam Ürün Sayısı: 1800

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# **📌 Tarayıcıyı başlat**
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# **📌 Çerezleri kabul etme fonksiyonu**
def accept_cookies():
    try:
        cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        cookie_button.click()
        print("✅ Çerezler kabul edildi!")
        time.sleep(2)
    except:
        print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Ürünleri çekme fonksiyonu**
def get_products():
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al
            try:
                review_count = title.find_element(By.XPATH, "./following::div[contains(@class, 'moria-ProductCard')]").text.strip()
            except:
                review_count = "0"  # Eğer yorum bulunamazsa 0 ata
            all_products.append((product_name, review_count))
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 Sayfa Sayısı ve URL Güncelleme**
max_pages = 25  # Kaç sayfa çekmek istediğini belirle
all_products = []  # Tüm ürünleri saklamak için liste

for page_num in range(1, max_pages + 1):
    url = f"https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa={page_num}"
    print(f"\n🌍 Sayfa {page_num} Yükleniyor: {url}")
    
    # Sayfayı aç
    driver.get(url)
    time.sleep(5)  # **Sayfanın yüklenmesini bekle**
    
    # **Çerezleri kabul et (ilk sayfada)**
    if page_num == 1:
        accept_cookies()

    # **Ürünleri çek**
    get_products()

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
# Out:
# 🌍 Sayfa 1 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=1
# ⚠️ Çerez butonu bulunamadı, devam ediliyor...
#
# 🌍 Sayfa 2 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=2
#
# 🌍 Sayfa 3 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=3
#
# 🌍 Sayfa 4 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=4
#
# 🌍 Sayfa 5 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=5
#
# 🌍 Sayfa 6 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=6
#
# 🌍 Sayfa 7 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=7
#
# 🌍 Sayfa 8 Yükleniyor: https://www.hepsiburada.com/bayan-giyim-urunleri-c-60004640?siralama=yorumsayisi&sayfa=8
#
# ...

# %%
# **📌 Sonuçları Yazdır ve Yorum Sayılarının Toplamını Hesapla**
total_reviews = 0  # Toplam yorum sayısı

print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    #print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
    
    # **Yorum Sayısını Noktadan Temizleyerek Tam Sayıya Çevir**
    try:
        reviews_clean = int(float(reviews.replace(".", "")))  # 1.512 → 1512
        total_reviews += reviews_clean
    except ValueError:
        print(f"⚠️ Hatalı yorum sayısı algılandı: {reviews}")  # Eğer hata olursa

# **📌 Toplam Yorum Sayısını Yazdır**
print(f"\n🔢 Toplam Yorum Sayısı: {total_reviews}")
print(f"\n🔢 Toplam Ürün Sayısı: {len(all_products)}")
# Out:
# ✅ Tüm Ürünler ve Yorum Sayıları:
#
# 🔢 Toplam Yorum Sayısı: 366508
#
# 🔢 Toplam Ürün Sayısı: 900

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# **📌 Tarayıcıyı başlat**
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# **📌 Çerezleri kabul etme fonksiyonu**
def accept_cookies():
    try:
        cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        cookie_button.click()
        print("✅ Çerezler kabul edildi!")
        time.sleep(2)
    except:
        print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Ürünleri çekme fonksiyonu**
def get_products():
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al
            try:
                review_count = title.find_element(By.XPATH, "./following::div[contains(@class, 'moria-ProductCard')]").text.strip()
            except:
                review_count = "0"  # Eğer yorum bulunamazsa 0 ata
            all_products.append((product_name, review_count))
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 Sayfa Sayısı ve URL Güncelleme**
max_pages = 5  # Kaç sayfa çekmek istediğini belirle
all_products = []  # Tüm ürünleri saklamak için liste

for page_num in range(1, max_pages + 1):
    url = f"https://www.hepsiburada.com/kozmetik-kisisel-bakim-urunleri-c-60001547?siralama=yorumsayisi&sayfa={page_num}"
    print(f"\n🌍 Sayfa {page_num} Yükleniyor: {url}")
    
    # Sayfayı aç
    driver.get(url)
    time.sleep(5)  # **Sayfanın yüklenmesini bekle**
    
    # **Çerezleri kabul et (ilk sayfada)**
    if page_num == 1:
        accept_cookies()

    # **Ürünleri çek**
    get_products()

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
# Out:
# 🌍 Sayfa 1 Yükleniyor: https://www.hepsiburada.com/kozmetik-kisisel-bakim-urunleri-c-60001547?siralama=yorumsayisi&sayfa=1
# ⚠️ Çerez butonu bulunamadı, devam ediliyor...
#
# 🌍 Sayfa 2 Yükleniyor: https://www.hepsiburada.com/kozmetik-kisisel-bakim-urunleri-c-60001547?siralama=yorumsayisi&sayfa=2
#
# 🌍 Sayfa 3 Yükleniyor: https://www.hepsiburada.com/kozmetik-kisisel-bakim-urunleri-c-60001547?siralama=yorumsayisi&sayfa=3
#
# 🌍 Sayfa 4 Yükleniyor: https://www.hepsiburada.com/kozmetik-kisisel-bakim-urunleri-c-60001547?siralama=yorumsayisi&sayfa=4
#
# 🌍 Sayfa 5 Yükleniyor: https://www.hepsiburada.com/kozmetik-kisisel-bakim-urunleri-c-60001547?siralama=yorumsayisi&sayfa=5
#
# ✅ Tüm Ürünler ve Yorum Sayıları:
# 1. 🖥️ Ürün: Powertec TR-901 Profesyonel Saç Kurutma Fön Makinesi | 💬 Yorum: 46.959
# 2. 🖥️ Ürün: Philips MG3720 Erkek Bakım Seti 7'si 1 arada Saç & Sakal Şekillendirici | 💬 Yorum: 25.101
# 3. 🖥️ Ürün: Xiaomi Mi 2 Yağ Ölçer Fonksiyonlu Akıllı Bluetooth Tartı Baskül | 💬 Yorum: 21.596
# ...

# %%
# **📌 Sonuçları Yazdır ve Yorum Sayılarının Toplamını Hesapla**
total_reviews = 0  # Toplam yorum sayısı

print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    #print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
    
    # **Yorum Sayısını Noktadan Temizleyerek Tam Sayıya Çevir**
    try:
        reviews_clean = int(float(reviews.replace(".", "")))  # 1.512 → 1512
        total_reviews += reviews_clean
    except ValueError:
        print(f"⚠️ Hatalı yorum sayısı algılandı: {reviews}")  # Eğer hata olursa

# **📌 Toplam Yorum Sayısını Yazdır**
print(f"\n🔢 Toplam Yorum Sayısı: {total_reviews}")
print(f"\n🔢 Toplam Ürün Sayısı: {len(all_products)}")
# Out:
# ✅ Tüm Ürünler ve Yorum Sayıları:
#
# 🔢 Toplam Yorum Sayısı: 1386942
#
# 🔢 Toplam Ürün Sayısı: 180

# %%
base_url = input("Lutfen URL giriniz").strip()
# Out:
# Lutfen URL giriniz https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi

# %%
all_products = []  # Tüm ürünleri saklamak için liste
basla=31

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# **📌 Tarayıcıyı başlat**
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# **📌 Çerezleri kabul etme fonksiyonu**
def accept_cookies():
    try:
        cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        cookie_button.click()
        print("✅ Çerezler kabul edildi!")
        time.sleep(2)
    except:
        print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Ürünleri çekme fonksiyonu**
def get_products():
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al
            try:
                review_count = title.find_element(By.XPATH, "./following::div[contains(@class, 'moria-ProductCard')]").text.strip()
            except:
                review_count = "0"  # Eğer yorum bulunamazsa 0 ata
            all_products.append((product_name, review_count))
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 Sayfa Sayısı ve URL Güncelleme**
max_pages = 40  # Kaç sayfa çekmek istediğini belirle
#all_products = []  # Tüm ürünleri saklamak için liste
basla=31

for page_num in range(basla, max_pages + 1):
    url = f"{base_url}&sayfa={page_num}"
    print(f"\n🌍 Sayfa {page_num} Yükleniyor: {url}")
    
    # Sayfayı aç
    driver.get(url)
    time.sleep(5)  # **Sayfanın yüklenmesini bekle**
    
    # **Çerezleri kabul et (ilk sayfada)**
    if page_num == 1:
        accept_cookies()

    # **Ürünleri çek**
    get_products()

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
# Out:
# 🌍 Sayfa 31 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=31
#
# 🌍 Sayfa 32 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=32
#
# 🌍 Sayfa 33 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=33
#
# 🌍 Sayfa 34 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=34
#
# 🌍 Sayfa 35 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=35
#
# 🌍 Sayfa 36 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=36
#
# 🌍 Sayfa 37 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=37
#
# 🌍 Sayfa 38 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=38
#
# ...

# %%
# **📌 Sonuçları Yazdır ve Yorum Sayılarının Toplamını Hesapla**
total_reviews = 0  # Toplam yorum sayısı

print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews) in enumerate(all_products, 1):
    #print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews}")
    
    # **Yorum Sayısını Noktadan Temizleyerek Tam Sayıya Çevir**
    try:
        reviews_clean = int(float(reviews.replace(".", "")))  # 1.512 → 1512
        total_reviews += reviews_clean
    except ValueError:
        print(f"⚠️ Hatalı yorum sayısı algılandı: {reviews}")  # Eğer hata olursa

# **📌 Toplam Yorum Sayısını Yazdır**
print(f"\n🔢 Toplam Yorum Sayısı: {total_reviews}")
print(f"\n🔢 Toplam Ürün Sayısı: {len(all_products)}")
# Out:
# ✅ Tüm Ürünler ve Yorum Sayıları:
#
# 🔢 Toplam Yorum Sayısı: 1050485
#
# 🔢 Toplam Ürün Sayısı: 1440

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# **📌 Kullanıcıdan URL Al**
base_url = input("Lütfen Hepsiburada ürün listesinin URL'sini girin: ").strip()

# **📌 Tarayıcıyı başlat**
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# **📌 Çerezleri kabul etme fonksiyonu**
def accept_cookies():
    try:
        cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        cookie_button.click()
        print("✅ Çerezler kabul edildi!")
        time.sleep(2)
    except:
        print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Ürünleri çekme fonksiyonu**
def get_products():
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al

            try:
                # **📌 Ürün Linkini Bulma (Üst Seviye <a> Tag'ini Kullanarak)**
                product_link = title.find_element(By.XPATH, "./ancestor::a").get_attribute("href")
            except:
                product_link = "Link Bulunamadı"

            try:
                # **📌 Yorum Sayısını Bulma**
                review_element = title.find_element(By.XPATH, "./following::div[@data-test-id='review']")
                review_count = review_element.text.strip()
            except:
                review_count = "0"  # Eğer yorum bulunamazsa 0 ata
            
            all_products.append((product_name, review_count, product_link))
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 Sayfa Sayısı ve URL Güncelleme**
max_pages = 2  # Kaç sayfa çekmek istediğini belirle
all_products = []  # Tüm ürünleri saklamak için liste

for page_num in range(1, max_pages + 1):
    url = f"{base_url}&sayfa={page_num}"
    print(f"\n🌍 Sayfa {page_num} Yükleniyor: {url}")
    
    # Sayfayı aç
    driver.get(url)
    time.sleep(5)  # **Sayfanın yüklenmesini bekle**
    
    # **Çerezleri kabul et (ilk sayfada)**
    if page_num == 1:
        accept_cookies()

    # **Ürünleri çek**
    get_products()

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler, Yorum Sayıları ve Linkleri:")
for i, (name, reviews, link) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews} | 🔗 Link: {link}")
# Out:
# Lütfen Hepsiburada ürün listesinin URL'sini girin:  https://www.hepsiburada.com/saglik-kisisel-bakim-urunleri-c-2147483633?siralama=yorumsayisi
# 🌍 Sayfa 1 Yükleniyor: https://www.hepsiburada.com/saglik-kisisel-bakim-urunleri-c-2147483633?siralama=yorumsayisi&sayfa=1
# ⚠️ Çerez butonu bulunamadı, devam ediliyor...
#
# 🌍 Sayfa 2 Yükleniyor: https://www.hepsiburada.com/saglik-kisisel-bakim-urunleri-c-2147483633?siralama=yorumsayisi&sayfa=2
#
# ✅ Tüm Ürünler, Yorum Sayıları ve Linkleri:
# 1. 🖥️ Ürün: Powertec TR-901 Profesyonel Saç Kurutma Fön Makinesi | 💬 Yorum: 46.959 | 🔗 Link: https://www.hepsiburada.com/powertec-tr-901-sac-kurutma-fon-makinesi-pm-HB000002J8XS
# 2. 🖥️ Ürün: Philips MG3720 Erkek Bakım Seti 7'si 1 arada Saç & Sakal Şekillendirici | 💬 Yorum: 25.101 | 🔗 Link: https://www.hepsiburada.com/philips-mg3720-erkek-bakim-seti-7-si-1-arada-sac-sakal-sekillendirici-pm-HB00000BTG0W
# ...

# %%
# **📌 Sonuçları Yazdır ve Yorum Sayılarının Toplamını Hesapla**
total_reviews = 0  # Toplam yorum sayısı

print("\n✅ Tüm Ürünler ve Yorum Sayıları:")
for i, (name, reviews, link) in enumerate(all_products, 1):  # Ürün adı, yorum sayısı ve link al
    #print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews} | 🔗 Link: {link}")
    
    # **Yorum Sayısını Sayıya Çevir ve Nokta İçeriyorsa Temizle**
    try:
        reviews_clean = int(reviews.replace(".", "").replace(",", ""))  # 1.512 → 1512, 1,512 → 1512
        total_reviews += reviews_clean
    except ValueError:
        print(f"⚠️ Hatalı yorum sayısı algılandı ve atlandı: {reviews}")  # Eğer hata olursa geç

# **📌 Toplam Yorum Sayısını Yazdır**
print(f"\n🔢 Toplam Yorum Sayısı: {total_reviews}")
print(f"📦 Toplam Ürün Sayısı: {len(all_products)}")
# Out:
# ✅ Tüm Ürünler ve Yorum Sayıları:
#
# 🔢 Toplam Yorum Sayısı: 698763
# 📦 Toplam Ürün Sayısı: 72

# %%
all_products
# Out:
# [('Powertec TR-901 Profesyonel Saç Kurutma Fön Makinesi',
#   '46.959',
#   'https://www.hepsiburada.com/powertec-tr-901-sac-kurutma-fon-makinesi-pm-HB000002J8XS'),
#  ("Philips MG3720 Erkek Bakım Seti 7'si 1 arada Saç & Sakal Şekillendirici",
#   '25.101',
#   'https://www.hepsiburada.com/philips-mg3720-erkek-bakim-seti-7-si-1-arada-sac-sakal-sekillendirici-pm-HB00000BTG0W'),
#  ('Xiaomi Mi 2 Yağ Ölçer Fonksiyonlu Akıllı Bluetooth Tartı Baskül',
#   '21.596',
#   'https://www.hepsiburada.com/xiaomi-mi-2-yag-olcer-fonksiyonlu-akilli-bluetooth-tarti-baskul-pm-HB00000BSEBP'),
#  ('Rexona Clinical Protection Shower Clean Kadın 45 ml',
#   '19.687',
#   'https://www.hepsiburada.com/rexona-clinical-protection-kadin-stick-deodorant-shower-clean-45-ml-pm-HB000003MOEG'),
#  ('Omron M2 Basic HEM-7121J-E Üst Koldan Ölçer Dijital Tansiyon Aleti',
#   '17.514',
#   'https://www.hepsiburada.com/omron-m2-basic-hem-7121j-e-ust-koldan-olcer-dijital-tansiyon-aleti-pm-sgomronbasic'),
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# **📌 Kullanıcıdan URL Al**
base_url = input("Lütfen Hepsiburada ürün listesinin URL'sini girin: ").strip()

# **📌 Tarayıcıyı başlat**
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# **📌 Çerezleri kabul etme fonksiyonu**
def accept_cookies():
    try:
        cookie_button = driver.find_element(By.ID, "onetrust-accept-btn-handler")
        cookie_button.click()
        print("✅ Çerezler kabul edildi!")
        time.sleep(2)
    except:
        print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

# **📌 Ürünleri çekme fonksiyonu**
def get_products():
    global total_reviews
    try:
        product_titles = driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
        
        for title in product_titles:
            product_name = title.text.strip()  # Ürün adını al

            try:
                # **📌 Ürün Linkini Bulma**
                product_link = title.find_element(By.XPATH, "./ancestor::a").get_attribute("href")
            except:
                product_link = "Link Bulunamadı"

            try:
                # **📌 Yorum Sayısını Bulma**
                review_element = title.find_element(By.XPATH, "./following::div[@data-test-id='review']")
                review_count = review_element.text.strip()
            except:
                review_count = "0"  # Eğer yorum bulunamazsa 0 ata

            # **📌 Yorum Sayısını Sayıya Çevir ve Toplamı Güncelle**
            try:
                reviews_clean = int(review_count.replace(".", "").replace(",", ""))  # 1.512 → 1512, 1,512 → 1512
                total_reviews += reviews_clean
            except ValueError:
                print(f"⚠️ Hatalı yorum sayısı algılandı ve atlandı: {review_count}")

            all_products.append((product_name, review_count, product_link))
    except:
        print("⚠️ Ürün başlıkları bulunamadı!")

# **📌 Sayfa Sayısı ve URL Güncelleme**
max_pages = 2  # Kaç sayfa çekmek istediğini belirle
all_products = []  # Tüm ürünleri saklamak için liste
total_reviews = 0  # Toplam yorum sayısını tutacak değişken

for page_num in range(1, max_pages + 1):
    url = f"{base_url}&sayfa={page_num}"
    print(f"\n🌍 Sayfa {page_num} Yükleniyor: {url}")
    
    # Sayfayı aç
    driver.get(url)
    time.sleep(5)  # **Sayfanın yüklenmesini bekle**
    
    # **Çerezleri kabul et (ilk sayfada)**
    if page_num == 1:
        accept_cookies()

    # **Ürünleri çek**
    get_products()

# **📌 Tarayıcıyı kapat**
driver.quit()

# **📌 Sonuçları Yazdır**
print("\n✅ Tüm Ürünler, Yorum Sayıları ve Linkleri:")
for i, (name, reviews, link) in enumerate(all_products, 1):
    print(f"{i}. 🖥️ Ürün: {name} | 💬 Yorum: {reviews} | 🔗 Link: {link}")

# **📌 Toplam Yorum ve Ürün Sayısını Yazdır**
print(f"\n🔢 Toplam Yorum Sayısı: {total_reviews}")
print(f"📦 Toplam Ürün Sayısı: {len(all_products)}")
# Out:
# Lütfen Hepsiburada ürün listesinin URL'sini girin:  https://www.hepsiburada.com/saglik-kisisel-bakim-urunleri-c-2147483633?siralama=yorumsayisi
# 🌍 Sayfa 1 Yükleniyor: https://www.hepsiburada.com/saglik-kisisel-bakim-urunleri-c-2147483633?siralama=yorumsayisi&sayfa=1
# ✅ Çerezler kabul edildi!
#
# 🌍 Sayfa 2 Yükleniyor: https://www.hepsiburada.com/saglik-kisisel-bakim-urunleri-c-2147483633?siralama=yorumsayisi&sayfa=2
#
# ✅ Tüm Ürünler, Yorum Sayıları ve Linkleri:
# 1. 🖥️ Ürün: Powertec TR-901 Profesyonel Saç Kurutma Fön Makinesi | 💬 Yorum: 46.959 | 🔗 Link: https://www.hepsiburada.com/powertec-tr-901-sac-kurutma-fon-makinesi-pm-HB000002J8XS
# 2. 🖥️ Ürün: Philips MG3720 Erkek Bakım Seti 7'si 1 arada Saç & Sakal Şekillendirici | 💬 Yorum: 25.101 | 🔗 Link: https://www.hepsiburada.com/philips-mg3720-erkek-bakim-seti-7-si-1-arada-sac-sakal-sekillendirici-pm-HB00000BTG0W
# ...

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

class UrunListesiAlma:
    def __init__(self, base_url, max_pages=10):
        self.base_url = base_url
        self.max_pages = max_pages
        self.all_products = []
        self.total_reviews = 0

        # **📌 Selenium Tarayıcıyı Başlat**
        options = Options()
        options.add_argument("--no-sandbox")
        options.add_argument("--disable-dev-shm-usage")
        self.driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    def accept_cookies(self):
        """Çerezleri kabul eder (varsa)."""
        try:
            cookie_button = self.driver.find_element(By.ID, "onetrust-accept-btn-handler")
            cookie_button.click()
            print("✅ Çerezler kabul edildi!")
            time.sleep(2)
        except:
            print("⚠️ Çerez butonu bulunamadı, devam ediliyor...")

    def get_products(self):
        """Ürünleri çeker ve listeye ekler."""
        try:
            product_titles = self.driver.find_elements(By.XPATH, "//h3[@data-test-id='product-card-name']")
            
            for title in product_titles:
                product_name = title.text.strip()  # Ürün adını al

                try:
                    # **📌 Ürün Linkini Bulma**
                    product_link = title.find_element(By.XPATH, "./ancestor::a").get_attribute("href")
                except:
                    product_link = "Link Bulunamadı"

                try:
                    # **📌 Yorum Sayısını Bulma**
                    review_element = title.find_element(By.XPATH, "./following::div[@data-test-id='review']")
                    review_count = review_element.text.strip()
                except:
                    review_count = "0"  # Eğer yorum bulunamazsa 0 ata

                # **📌 Yorum Sayısını Sayıya Çevir ve Toplamı Güncelle**
                try:
                    reviews_clean = int(review_count.replace(".", "").replace(",", ""))  # 1.512 → 1512, 1,512 → 1512
                    self.total_reviews += reviews_clean
                except ValueError:
                    print(f"⚠️ Hatalı yorum sayısı algılandı ve atlandı: {review_count}")
                    reviews_clean = 0

                self.all_products.append([product_name, reviews_clean, product_link])
        except:
            print("⚠️ Ürün başlıkları bulunamadı!")

    def scrape(self, page_limit=None):
        """
        Hepsiburada'dan ürünleri çeker ve Pandas DataFrame olarak döndürür.
        - page_limit: Kaç sayfanın verisini almak istiyorsan belirtebilirsin.
                      Varsayılan olarak None, yani `self.max_pages` kadar çeker.
        """
        if page_limit is None:
            page_limit = self.max_pages  # Eğer belirtilmezse, varsayılan `max_pages` değeri kullanılır

        for page_num in range(1, page_limit + 1):
            url = f"{self.base_url}&sayfa={page_num}"
            print(f"\n🌍 Sayfa {page_num} Yükleniyor: {url}")
            
            # Sayfayı aç
            self.driver.get(url)
            time.sleep(5)  # **Sayfanın yüklenmesini bekle**
            
            # **Çerezleri kabul et (ilk sayfada)**
            if page_num == 1:
                self.accept_cookies()

            # **Ürünleri çek**
            self.get_products()

        # **📌 Tarayıcıyı kapat**
        self.driver.quit()

        # **📌 Sonuçları Pandas DataFrame'e Çevir**
        df = pd.DataFrame(self.all_products, columns=["Product_Name", "Comment_Count", "Link"])

        # **📌 Toplam Yorum ve Ürün Sayısını Yazdır**
        print(f"\n🔢 Toplam Yorum Sayısı: {self.total_reviews}")
        print(f"📦 Toplam Ürün Sayısı: {len(self.all_products)}")

        # **📌 DataFrame'i Return Et**
        return df

# **📌 Kullanım**
if __name__ == "__main__":
    base_url = input("Lütfen Hepsiburada ürün listesinin URL'sini girin: ").strip()
    scraper = UrunListesiAlma(base_url)

    # Kullanıcı kaç sayfa çekeceğini belirleyebilir
    page_limit = 2 #int(input("Kaç sayfa verisini almak istiyorsunuz? (Varsayılan: 5) ") or 5)

    product_df = scraper.scrape(page_limit=page_limit)

    # **📌 Sonuçları Tabloda Yazdır**
    print("\n✅ Ürünler Tablosu:")
    print(product_df.to_string(index=False))  # Daha düzenli yazdırma
# Out:
# Lütfen Hepsiburada ürün listesinin URL'sini girin:  https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi
# 🌍 Sayfa 1 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=1
# ⚠️ Çerez butonu bulunamadı, devam ediliyor...
#
# 🌍 Sayfa 2 Yükleniyor: https://www.hepsiburada.com/sac-bakim-urunleri-c-26012111?siralama=yorumsayisi&sayfa=2
#
# 🔢 Toplam Yorum Sayısı: 345795
# 📦 Toplam Ürün Sayısı: 72
#
# ✅ Ürünler Tablosu:
#                                                                                                          Product_Name  Comment_Count                                                                                                                                                               Link
# ...

# %%
product_df
# Out:
#                                          Product_Name  Comment_Count  \
# 0   Powertec TR-901 Profesyonel Saç Kurutma Fön Ma...          46961
# 1        Nascita Pro Üç Boyutlu Oval Saç Fırçası - 02          14553
# 2   HC Care Complex Bitkisel Saç Bakım Kompleksi -...          14450
# 3   URBAN Care Expert Serisi Biotin ve Kafein Saç ...          11299
# 4             Bioxcin Forte Şampuan 300 ml 3 Al 2 Öde          10578
# ..                                                ...            ...
# 67                 Purple Mat Wax - Matte Past 100 ml           2348
# 68  Ducray Anaphase+ Saç Dökülmesine Karşı Şampuan...           2285
# 69  OGX Dolgunlaştırıcı Biotin & Kolajen Sülfatsız...           2242
# 70  Pantene Doğal Sentez Argan Yağlı Elixir 100 ml...           2240
# 71               Sebamed Kepeğe Karşı Şampuan 1000 ml           2240
#
#                                                  Link
# 0   https://www.hepsiburada.com/powertec-tr-901-sa...
# ...
